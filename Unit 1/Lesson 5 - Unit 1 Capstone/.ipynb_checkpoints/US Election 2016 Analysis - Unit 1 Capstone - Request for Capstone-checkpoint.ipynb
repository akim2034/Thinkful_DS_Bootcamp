# %%
# Import Python libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re 
# %matplotlib inline

# %%
# Upload datasets. 
county_facts = pd.read_csv("county_facts.csv")
county_facts_dict = pd.read_csv("county_facts_dictionary.csv")
primary_results = pd.read_csv("primary_results.csv")

# %%
# Check primary results dataset.
primary_results.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
#primary_results['fips'] = pd.to_numeric(primary_results['fips'], errors = 'ignore')#

# %%
#county_facts_new['fips'] = pd.to_numeric(county_facts_new['fips'], errors = 'ignore')

# %%
# Check county facts dataset.
county_facts.head()
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214    ...      SBO415207  \
# 0  308745538        6.2       23.1       14.5    ...            8.3
# 1    4779736        6.1       22.8       15.3    ...            1.2
# 2      54571        6.0       25.2       13.8    ...            0.7
# 3     182265        5.6       22.2       18.7    ...            1.3
# 4      27457        5.7       21.2       16.5    ...            0.0
#
#    SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# ...

# %%
# Check county facts dictionary dataset.
county_facts_dict.head()
# Out:
#   column_name                                        description
# 0   PST045214                          Population, 2014 estimate
# 1   PST040210          Population, 2010 (April 1) estimates base
# 2   PST120214  Population, percent change - April 1, 2010 to ...
# 3   POP010210                                   Population, 2010
# 4   AGE135214               Persons under 5 years, percent, 2014

# %%
# Filter for rows without a state abbreviation and for all row but fips = 0.
county_facts_state = county_facts[(county_facts['state_abbreviation'].isnull()) & (county_facts['fips'] != 0)]

# Allow max columns for all heads.
pd.options.display.max_columns = None

# Check updated county facts by state dataset. 
county_facts_state.head()
# Out:
#      fips   area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 1    1000     Alabama                NaN    4849377    4780127        1.4
# 69   2000      Alaska                NaN     736732     710249        3.7
# 99   4000     Arizona                NaN    6731484    6392310        5.3
# 115  5000    Arkansas                NaN    2966369    2915958        1.7
# 191  6000  California                NaN   38802500   37254503        4.2
#
#      POP010210  AGE135214  AGE295214  AGE775214  SEX255214  RHI125214  \
# 1      4779736        6.1       22.8       15.3       51.5       69.7
# 69      710231        7.4       25.3        9.4       47.4       66.9
# 99     6392017        6.4       24.1       15.9       50.3       83.7
# 115    2915918        6.5       23.8       15.7       50.9       79.7
# 191   37253956        6.5       23.6       12.9       50.3       73.2
#
#      RHI225214  RHI325214  RHI425214  RHI525214  RHI625214  RHI725214  \
# ...

# %%
# Organize county facts data with only the desired columns. 
state_facts = county_facts_state.reset_index()[['fips', 'area_name', 'state_abbreviation', 'PST045214', 'AGE295214', 'SEX255214',
                                               'RHI125214', 'RHI225214', 'RHI325214', 'RHI425214', 'RHI525214', 'RHI625214', 
                                               'POP645213', 'POP815213', 'EDU635213', 'EDU685213', 'VET605213', 'LFE305213', 
                                               'INC110213', 'PVY020213', 'SBO001207', 'SBO315207', 'SBO115207', 'SBO215207', 
                                               'SBO515207', 'SBO415207', 'SBO015207', 'POP060210']]

# Create new legible names for the columns.
state_facts.columns = ['fips', 'state', 'state_abbreviation', 'Population_2014', '18_and_younger', 'Female', 'White', 'Black', 
                            'American_Indian_Alaskan_Native', 'Asian', 'Native_Hawaiian_Pacific_Islander', 'Two_or_More_Races',
                            'Foreign_born_persons', 'Language_other_than_English_spoken_at_home', 'High_school', 'College', 
                            'Veterans', 'Commute', 'Median_household_income', 'Poverty', 'Total_number_of_firms', 
                            'Black_owned_firms', 'American_Indian_Alaska_Native_owned_firms', 'Asian_owned_firms', 
                            'Native_Hawaiian_and_Other_Pacific_Islander_owned_firms', 'Hispanic_owned_firms', 
                            'Hispanic_owned_firms', 'Population_per_square_mile']

# Check dataset for new county facts.
state_facts.head()
# Out:
#    fips       state state_abbreviation  Population_2014  18_and_younger  \
# 0  1000     Alabama                NaN          4849377            22.8
# 1  2000      Alaska                NaN           736732            25.3
# 2  4000     Arizona                NaN          6731484            24.1
# 3  5000    Arkansas                NaN          2966369            23.8
# 4  6000  California                NaN         38802500            23.6
#
#    Female  White  Black  American_Indian_Alaskan_Native  Asian  \
# 0    51.5   69.7   26.7                             0.7    1.3
# 1    47.4   66.9    3.9                            14.8    6.1
# 2    50.3   83.7    4.7                             5.3    3.3
# 3    50.9   79.7   15.6                             1.0    1.5
# 4    50.3   73.2    6.5                             1.7   14.4
#
#    Native_Hawaiian_Pacific_Islander  Two_or_More_Races  Foreign_born_persons  \
# ...

# %%
democrat_states = primary_results[primary_results['party'] == 'Democrat']
democrat_states
# Out:
#          state state_abbreviation       county     fips     party  \
# 0      Alabama                 AL      Autauga   1001.0  Democrat
# 1      Alabama                 AL      Autauga   1001.0  Democrat
# 2      Alabama                 AL      Baldwin   1003.0  Democrat
# 3      Alabama                 AL      Baldwin   1003.0  Democrat
# 4      Alabama                 AL      Barbour   1005.0  Democrat
# 5      Alabama                 AL      Barbour   1005.0  Democrat
# 6      Alabama                 AL         Bibb   1007.0  Democrat
# 7      Alabama                 AL         Bibb   1007.0  Democrat
# 8      Alabama                 AL       Blount   1009.0  Democrat
# 9      Alabama                 AL       Blount   1009.0  Democrat
# 10     Alabama                 AL      Bullock   1011.0  Democrat
# 11     Alabama                 AL      Bullock   1011.0  Democrat
# 12     Alabama                 AL       Butler   1013.0  Democrat
# ...

# %%
democrat_states_sum = democrat_states.groupby(['state'])['votes'].sum()
democrat_states_sum.columns = ['state', 'democrat_votes']
democrat_states_sum.head()
# Out:
# state
# Alabama        386327
# Alaska            539
# Arizona        399097
# Arkansas       209448
# California    3442623
# Name: votes, dtype: int64

# %%
# Merge primary results and state facts on the same state. 
results_state_facts = pd.merge(democrat_states_sum,state_facts, on = ['state'])

# Check dataset. 
results_state_facts.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-f45f5e96883b> in <module>()
#       1 # Merge primary results and state facts on the same state.
# ----> 2 results_state_facts = pd.merge(democrat_states_sum,state_facts, on = ['state'])
#       3
#       4 # Check dataset.
#       5 results_state_facts.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# ...

# %%
# Create new dataset for just democrat votes.
democrat_states = results_state_facts[results_state_facts['party'] == 'Democrat']

# Check dataset.
democrat_states.head()
# Out:
#      state state_abbreviation_x   county  fips_x     party        candidate  \
# 0  Alabama                   AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                   AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                   AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                   AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                   AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes  fips_y state_abbreviation_y  Population_2014  \
# 0    544           0.182    1000                  NaN          4849377
# 1   2387           0.800    1000                  NaN          4849377
# 2   2694           0.329    1000                  NaN          4849377
# 3   5290           0.647    1000                  NaN          4849377
# 4    222           0.078    1000                  NaN          4849377
#
#    18_and_younger  Female  White  Black  American_Indian_Alaskan_Native  \
# ...

# %%
# Create new dataset for just republican votes.
republican_states = results_state_facts[results_state_facts['party'] == 'Republican']

# Check dataset.
republican_states.head()
# Out:
#        state state_abbreviation_x   county  fips_x       party     candidate  \
# 134  Alabama                   AL  Autauga  1001.0  Republican    Ben Carson
# 135  Alabama                   AL  Autauga  1001.0  Republican  Donald Trump
# 136  Alabama                   AL  Autauga  1001.0  Republican   John Kasich
# 137  Alabama                   AL  Autauga  1001.0  Republican   Marco Rubio
# 138  Alabama                   AL  Autauga  1001.0  Republican      Ted Cruz
#
#      votes  fraction_votes  fips_y state_abbreviation_y  Population_2014  \
# 134   1764           0.146    1000                  NaN          4849377
# 135   5387           0.445    1000                  NaN          4849377
# 136    421           0.035    1000                  NaN          4849377
# 137   1785           0.148    1000                  NaN          4849377
# 138   2482           0.205    1000                  NaN          4849377
#
# ...

# %%
print(len(democrat_states))
print(len(republican_states))
print(len(republican_states) + len(democrat_states))
# Out:
# 8959
# 15652
# 24611

# %%
democrat_states_sum = democrat_states.groupby(['state'])['votes'].sum()
democrat_states_sum.columns = ['state', 'democrat_votes']
democrat_states_sum.head()
# Out:
# state
# Alabama        386327
# Alaska            539
# Arizona        399097
# Arkansas       209448
# California    3442623
# Name: votes, dtype: int64

# %%
sns.distplot(democrat_states['White']);

# %%
sns.distplot(republican_states['White']);

# %%
sns.distplot(democrat_states['Black']);

# %%
sns.distplot(republican_states['Black']);

# %%
sns.distplot(democrat_states['Female']);

# %%
sns.distplot(republican_states['Female']);

# %%
sns.boxplot(democrat_states['College']);

# %%
sns.boxplot(republican_states['College']);

# %%
sns.violinplot(democrat_states['Population_per_square_mile']);

# %%
sns.violinplot(republican_states['Population_per_square_mile']);

# %%
sns.swarmplot(x='Winning_party', y="White", data=state_facts);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b4d20bcefcd9> in <module>()
# ----> 1 sns.swarmplot(x='Winning_party', y="White", data=state_facts);
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2765
#    2766     plotter = _SwarmPlotter(x, y, hue, data, order, hue_order,
# -> 2767                             dodge, orient, color, palette)
#    2768     if ax is None:
#    2769         ax = plt.gca()
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, dodge, orient, color, palette)
#    1191                  dodge, orient, color, palette):
#    1192         """Initialize the plotter."""
# ...

# %%
sns.swarmplot(x='Winning_party', y="Asian", data=state_facts);

# %%
sns.boxplot(x="Winning_party", y="Poverty", data=state_facts);

# %%
sns.boxplot(x="Winning_party", y="Rvotes_of_population", data=state_facts);
